# %%
import requests
from datetime import datetime, timedelta
import xml.etree.ElementTree as ET
import logging

logging.basicConfig(level=logging.INFO)

from tqdm.contrib.concurrent import (
    process_map,
)  # Import process_map for multiprocessing


def fetch_citation_count(pmid):
    """
    Fetch citation count for a given PMID.
    """
    elink_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi"
    params = {
        "dbfrom": "pubmed",
        "db": "pubmed",
        "id": pmid,
        "linkname": "pubmed_pubmed_citedin",  # Link to citing articles
        "retmode": "xml",
    }

    response = requests.get(elink_url, params=params)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        citation_count = len(root.findall(".//LinkSetDb/Link"))
        return citation_count
    return 0  # Return 0 if unable to fetch citation count


def fetch_citations_for_papers(papers):
    """
    Fetch citation counts for a list of papers in parallel.
    """
    pmids = [paper["pmid"] for paper in papers]
    citation_counts = process_map(fetch_citation_count, pmids, max_workers=10)
    for paper, citation_count in zip(papers, citation_counts):
        paper["citations"] = citation_count
    return papers


def fetch_recent_papers(query, days_ago=90, n_articles=10000):
    """
    Fetch recent papers from PubMed based on a query and include citation counts.
    """
    # Calculate date range
    end_date = datetime.today()
    start_date = end_date - timedelta(days=days_ago)
    start_date_str = start_date.strftime("%Y/%m/%d")
    end_date_str = end_date.strftime("%Y/%m/%d")

    # PubMed API endpoint
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": f'({query}) AND ("{start_date_str}"[Date - Publication] : "{end_date_str}"[Date - Publication])',
        "retmax": n_articles,
        "usehistory": "y",
    }

    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        root = ET.fromstring(response.content)
        webenv = root.find(".//WebEnv").text
        query_key = root.find(".//QueryKey").text

        # Fetch actual paper details using efetch
        fetch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
        fetch_params = {
            "db": "pubmed",
            "query_key": query_key,
            "WebEnv": webenv,
            "retmode": "xml",
            "rettype": "abstract",
            "retmax": n_articles,
        }
        fetch_response = requests.get(fetch_url, params=fetch_params)
        if fetch_response.status_code == 200:
            fetch_root = ET.fromstring(fetch_response.content)
            papers = []
            for article in fetch_root.findall(".//PubmedArticle"):
                title = article.find(".//ArticleTitle").text
                pmid = article.find(".//PMID").text
                link = f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/"

                # Extract keywords
                keyword_list = article.find(".//KeywordList")

                keywords = (
                    [keyword.text for keyword in keyword_list.findall(".//Keyword")]
                    if keyword_list is not None
                    else []
                )
                papers.append(
                    {"title": title, "pmid": pmid, "link": link, "keywords": keywords}
                )
            return papers
    return "Failed to fetch papers or no papers found."


# Example usage
journals = [
    "Bioinformatics",
    "BMC Bioinformatics",
    "Nucleic Acids Research",
    "Genome Research",
    "Genome Biology",
    "PLOS Computational Biology",
    "Journal of Computational Biology",
    "Journal of Biomedical Informatics",
    "Journal of Cheminformatics",
    "Molecular Informatics",
    "Journal of Chemical Information and Modeling",
    "Nature Machine Intelligence",
    "IEEE/ACM Transactions on Computational Biology and Bioinformatics",
    "Computational and Structural Biotechnology Journal",
    "Briefings in Bioinformatics",
    "Systems Biology and Applications",
    "BioSystems",
    "Algorithms for Molecular Biology",
    "BMC Genomics",
    "BMC Systems Biology",
    "BMC Evolutionary Biology",
    "BioData Mining",
    "PLOS Genetics",
    "Frontiers in Genetics",  # Bioinformatics and Computational Biology section
    "Journal of Proteome Research",
    "Proteins: Structure, Function, and Bioinformatics",
    "Molecular Systems Biology",
    "Cell Systems",
    "GigaScience",
    "Nature Biomedical Engineering",  # While broader, it includes significant bioinformatics research.
    "Patterns (Cell Press)",  # Focuses on data science that impacts science and society, including bioinformatics.
]


# Constructing the query part for journals
journal_queries = ['"' + journal + '"[Journal]' for journal in journals]
joined_journal_query = " OR ".join(journal_queries)

query = 'chemoinformatics OR "AI biomedicine"'
papers = fetch_recent_papers(joined_journal_query)


logging.info(f"Nº of papers: {len(papers)}")
# Out:
# INFO:root:Nº of papers: 2676

# %%
import requests
from datetime import datetime, timedelta
import xml.etree.ElementTree as ET
import logging

# %%
logging.info(f"Nº of papers: {len(papers)}")
# Out:
# INFO:root:Nº of papers: 2676

# %%
papers = fetch_citations_for_papers(papers)
# Out:
# /tmp/ipykernel_261846/607987373.py:39: TqdmWarning: Iterable length 2676 > 1000 but `chunksize` is not set. This may seriously degrade multiprocess performance. Set `chunksize=1` or more.
#   citation_counts = process_map(fetch_citation_count, pmids, max_workers=10)
# 100%|██████████| 2676/2676 [02:20<00:00, 19.09it/s]

# %%
logging.info(
    f"Nº of papers w/ citations in less than 3 months: {len([p for p in papers if p['citations'] > 0])}"
)
# Out:
# INFO:root:Nº of papers w/ citations in less than 3 months: 45

# %%
[p for p in papers if p["citations"] > 0]
# Out:
# [{'title': 'Counterfactual formulation of patient-specific root causes of disease.',
#   'pmid': '38191012',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38191012/',
#   'keywords': ['Causal discovery',
#    'Causal inference',
#    'Computational medicine',
#    'Precision medicine',
#    'Root cause analysis'],
#   'citations': 1},
#  {'title': 'Structural coverage of the human interactome.',
#   'pmid': '38180828',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38180828/',
#   'keywords': ['AlphaFold2',
#    'PDB',
#    'homology modeling databases',
#    'human interactome',
#    'human proteome',
#    'protein complexes',
#    'structural coverage'],
#   'citations': 1},
#  {'title': 'Relative molecule self-attention transformer.',
#   'pmid': '38173009',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38173009/',
#   'keywords': ['Molecular property prediction',
#    'Molecular self-attention',
#    'Neural networks pre-training'],
#   'citations': 2},
#  {'title': 'Cohesin and CTCF do not assemble TADs in ',
#   'pmid': '38129077',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38129077/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Revisiting chromatin packaging in mouse sperm.',
#   'pmid': '38129076',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38129076/',
#   'keywords': [],
#   'citations': 3},
#  {'title': 'Molecular traces of Drosophila hemocytes reveal transcriptomic conservation with vertebrate myeloid cells.',
#   'pmid': '38113249',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38113249/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Restoration of sensory feedback from the foot and reduction of phantom limb pain via closed-loop spinal cord stimulation.',
#   'pmid': '38097809',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38097809/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Dynamical flexible inference of nonlinear latent factors and structures in neural population activity.',
#   'pmid': '38082181',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38082181/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Screening for lipid nanoparticles that modulate the immune activity of helper T cells towards enhanced antitumour activity.',
#   'pmid': '38082180',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38082180/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Macroscopic resting-state brain dynamics are best described by linear models.',
#   'pmid': '38082179',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38082179/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Machine learning analysis of the T\xa0cell receptor repertoire identifies sequence features of self-reactivity.',
#   'pmid': '38061355',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38061355/',
#   'keywords': ['CD4 T cells',
#    'CD5',
#    'CDR3 beta chain',
#    'T cell receptor',
#    'chronic infection',
#    'heterogeneity',
#    'machine learning',
#    'retrogenic mice',
#    'self-reactivity',
#    'thymic development'],
#   'citations': 1},
#  {'title': 'Lysine acetylation regulates the AT-rich DNA possession ability of H-NS.',
#   'pmid': '38059366',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38059366/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Programming co-assembled peptide nanofiber morphology via anionic amino acid type: Insights from molecular dynamics simulations.',
#   'pmid': '38048311',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38048311/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Enzymic recognition of amino acids drove the evolution of primordial genetic codes.',
#   'pmid': '38048305',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38048305/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'MODOMICS: a database of RNA modifications and related information. 2023 update.',
#   'pmid': '38015436',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38015436/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'VIAMD: a Software for Visual Interactive Analysis of Molecular Dynamics.',
#   'pmid': '38011026',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/38011026/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'EMDB-the Electron Microscopy Data Bank.',
#   'pmid': '37994703',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37994703/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'ABC-HuMi: the Atlas of Biosynthetic Gene Clusters in the Human Microbiome.',
#   'pmid': '37994699',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37994699/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'A transformer-based deep learning approach for fairly predicting post-liver transplant risk factors.',
#   'pmid': '37992791',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37992791/',
#   'keywords': ['Fairness',
#    'Liver transplantation',
#    'Multi-task learning',
#    'Risk prediction'],
#   'citations': 1},
#  {'title': 'TarBase-v9.0 extends experimentally supported miRNA-gene interactions to cell-types and virally encoded miRNAs.',
#   'pmid': '37986224',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37986224/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'A methodology of phenotyping ICU patients from EHR data: High-fidelity, personalized, and interpretable phenotypes estimation.',
#   'pmid': '37984547',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37984547/',
#   'keywords': ['Data assimilation',
#    'Data mining',
#    'Electronic health record',
#    'Knowledge representation with machine learning',
#    'Phenotyping',
#    'Physiological modeling'],
#   'citations': 1},
#  {'title': 'Eukaryotic RNA-guided endonucleases evolved from a unique clade of bacterial enzymes.',
#   'pmid': '37971304',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37971304/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'DDBJ update in 2023: the MetaboBank for metabolomics data and associated metadata.',
#   'pmid': '37971299',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37971299/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'The European Nucleotide Archive in 2023.',
#   'pmid': '37956313',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37956313/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'VarCards2: an integrated genetic and clinical database for ACMG-AMP variant-interpretation guidelines in the human whole genome.',
#   'pmid': '37956311',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37956311/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'A new paradigm for molecular dynamics databases: the COVID-19 database, the legacy of a titanic community effort.',
#   'pmid': '37953362',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37953362/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'TATDN2 resolution of R-loops is required for survival of BRCA1-mutant cancer cells.',
#   'pmid': '37953292',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37953292/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'DrugBank 6.0: the DrugBank Knowledgebase for 2024.',
#   'pmid': '37953279',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37953279/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'To let go or not to let go: how ParA can impact the release of the chromosomal anchoring in Caulobacter crescentus.',
#   'pmid': '37933842',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37933842/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'The ChEMBL Database in 2023: a drug discovery platform spanning multiple bioactivity data types and time periods.',
#   'pmid': '37933841',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37933841/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'UTexas Aptamer Database: the collection and long-term preservation of aptamer sequence information.',
#   'pmid': '37904593',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37904593/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'ViralZone 2024 provides higher-resolution images and advanced virus-specific resources.',
#   'pmid': '37897348',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37897348/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'SPIRE: a Searchable,\xa0Planetary-scale mIcrobiome REsource.',
#   'pmid': '37897342',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37897342/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'CasPEDIA Database: a functional classification system for class 2 CRISPR-Cas enzymes.',
#   'pmid': '37889041',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37889041/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'GenBank 2024 Update.',
#   'pmid': '37889039',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37889039/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'CDS-DB, an omnibus for patient-derived gene expression signatures induced by cancer treatment.',
#   'pmid': '37889038',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37889038/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'UniTmp: unified resources for transmembrane proteins.',
#   'pmid': '37870462',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37870462/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'LIPID MAPS: update to databases and tools for the lipidomics community.',
#   'pmid': '37855672',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37855672/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'Two mitochondrial HMG-box proteins, Cim1 and Abf2, antagonistically regulate mtDNA copy number in Saccharomyces cerevisiae.',
#   'pmid': '37850632',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37850632/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'Fluorescence lifetime of injected indocyanine green as a universal marker of solid tumours in patients.',
#   'pmid': '37845517',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37845517/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'SORC: an integrated spatial omics resource in cancer.',
#   'pmid': '37811897',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37811897/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'NMPFamsDB: a database of novel protein families from microbial metagenomes and metatranscriptomes.',
#   'pmid': '37811892',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37811892/',
#   'keywords': [],
#   'citations': 1},
#  {'title': 'SCAR: Single-cell and Spatially-resolved Cancer Resources.',
#   'pmid': '37739405',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37739405/',
#   'keywords': [],
#   'citations': 2},
#  {'title': 'TTD: Therapeutic Target Database describing target druggability information.',
#   'pmid': '37713619',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37713619/',
#   'keywords': [],
#   'citations': 3},
#  {'title': 'Detection of viral RNAs at ambient temperature via reporter proteins produced through the target-splinted ligation of DNA probes.',
#   'pmid': '37142844',
#   'link': 'https://pubmed.ncbi.nlm.nih.gov/37142844/',
#   'keywords': [],
#   'citations': 1}]

# %%
import tweepy

# Replace these with your Twitter API credentials
consumer_key = "YOUR_CONSUMER_KEY"
consumer_secret = "YOUR_CONSUMER_SECRET"
access_token = "1701547786188054528-FFAWFV8sikP81RXmUJN8TbtMaL3x52"
access_token_secret = "BX4rQpWpn4lLIh0S47xVYQDa17wjR79laS2nOTqqxKKQY"

# Authenticate to Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Create API object
api = tweepy.API(auth)
