# %% [markdown]
# # SQL

# %% [markdown]
# ## Create Signature Table

# %%
# 1. Imports, Variables, Functions
import psycopg2
import pandas as pd
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# SQL variables
dbname = "ilincs"
user = "ddalton"
password = "Teclado$$$111"
host = "localhost"
path_data = "../../data/iLINCS/signatures.csv"
table_name = "signatures"
primary_key = "signatureid"
int_columns = ["nCtrSamples", "nTrtSamples", "pubChemID"]  # INT columns - rest TEXT
drop_table = False

# 2. Load Data
try:
    df_data = pd.read_csv(path_data)
    logging.info("Data loaded successfully.")
except FileNotFoundError:
    logging.error("Data file not found. Please check the file path.")
    exit()

# get max length for each
max_lengths = [max([len(str(n)) for n in df_data[c].to_list()]) for c in df_data.columns]

# Convert specified integer columns and handle NaN by replacing with 0
for col in int_columns:
    df_data[col] = pd.to_numeric(df_data[col], errors='coerce').fillna(0).astype(int)

# For other columns, replace NaN with None (which will become NULL in SQL)
for col in df_data.columns:
    if col not in int_columns:
        df_data[col] = df_data[col].where(pd.notnull(df_data[col]), None)
# 3. Connect with Database
try:
    conn = psycopg2.connect(dbname=dbname, user=user, password=password, host=host)
    logging.info("Connected to the database successfully.")
except psycopg2.OperationalError as e:
    logging.error(f"Unable to connect to the database: {e}")
    exit()

# 4. Create Cursor Object
cursor = conn.cursor()

# 5. Check if Table Exists and Delete Data if It Does

# Check if the table exists and drop it if it does
if drop_table:
    try:
        cursor.execute(f"DROP TABLE IF EXISTS {table_name};")
        conn.commit()
        print(f"Table {table_name} dropped successfully if it existed.")
    except psycopg2.Error as e:
        print(f"An error occurred: {e}")
        conn.rollback()
    finally:
        # Close cursor and connection
        cursor.close()
        conn.close()


cursor.execute("SELECT EXISTS(SELECT * FROM information_schema.tables WHERE table_name=%s)", (table_name,))
table_exists = cursor.fetchone()[0]

if table_exists:
    try:
        cursor.execute(f"DELETE FROM {table_name};")
        conn.commit()
        logging.info(f"Existing data in table {table_name} deleted successfully.")
    except psycopg2.Error as e:
        logging.error(f"An error occurred while deleting data from the table: {e}")
        cursor.close()
        conn.close()
        exit()
else:
    # Create table if it does not exist
    column_text = ", ".join(f"{c} VARCHAR({n + 10})" if c not in int_columns else f"{c} INT" for c, n in zip(df_data.columns, max_lengths))
    create_table_query = f"CREATE TABLE {table_name} ({column_text}, PRIMARY KEY({primary_key}));"
    try:
        cursor.execute(create_table_query)
        conn.commit()
        logging.info(f"Table {table_name} created successfully.")
    except psycopg2.Error as e:
        logging.error(f"An error occurred while creating the table: {e}")
        cursor.close()
        conn.close()
        exit()
# Out:
# /tmp/ipykernel_169994/1186245160.py:22: DtypeWarning: Columns (0,3,7,8,9,10,15,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_data = pd.read_csv(path_data)
# 2023-11-27 16:01:13,716 - INFO - Data loaded successfully.
# 2023-11-27 16:01:14,359 - INFO - Connected to the database successfully.
# 2023-11-27 16:01:14,362 - INFO - Existing data in table signatures deleted successfully.

# %%
for c in df_data.columns:
    if c not in int_columns:
        print(f"{c} str")
    else:
        print(f"{c} int")
# Out:
# antibodytarget str
# cellline str
# tissue str
# cid str
# compound str
# concentration str
# concordancetable str
# datasetid str
# factor str
# level1 str
# level2 str
# libraryid str
# lincspertid str
# nCtrSamples int
# nTrtSamples int
# peaktype str
# platform str
# signatureid str
# lincsSigID str
# organism str
# clueIoCompound str
# integratedMoas str
# GeneTargets str
# time str
# treatment str
# perturbagenID str
# stitchID str
# pubChemID int
# is_exemplar str
# pert_type str

# %%
# 6. Dump Data into Table
data_tuples = list(df_data.itertuples(index=False, name=None))
insert_query = f"INSERT INTO {table_name} ({', '.join(df_data.columns)}) VALUES (%s" + ", %s"*(len(df_data.columns)-1) + ")"

try:
    with conn:
        with conn.cursor() as curs:
            for record in data_tuples:
                try:
                    curs.execute(insert_query, record)
                except psycopg2.Error as e:
                    logging.error(f"Error inserting record {record}: {e}")
                    # Optionally, you can break the loop after logging the first error
                    break  
    logging.info(f"Data dumped into {table_name} successfully.")
except psycopg2.Error as e:
    logging.error(f"An error occurred while inserting data into the table: {e}")
    conn.rollback()
    exit()
# Out:
# 2023-11-27 14:02:10,881 - INFO - Data dumped into signatures successfully.

# %% [markdown]
# ## Create Table Dataset

# %%
# 1. Imports, Variables, Functions
import psycopg2
import pandas as pd
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# SQL variables
dbname = "ilincs"
user = "ddalton"
password = "Teclado$$$111"
host = "localhost"
path_data = "../../data/iLINCS/datasets.csv"
table_name = "datasets"
primary_keys = ["experiment","portal"]
int_columns = ["nsamples"]  # INT columns - rest TEXT
drop_table = True
foreign_key = "SourceID"
parent_table = "signatures"
parent_id = "datasetid"
# 2. Load Data
try:
    df_data = pd.read_csv(path_data)
    logging.info("Data loaded successfully.")
except FileNotFoundError:
    logging.error("Data file not found. Please check the file path.")
    exit()

# get max length for each
max_lengths = [max([len(str(n)) for n in df_data[c].to_list()]) for c in df_data.columns]

# Convert specified integer columns and handle NaN by replacing with 0
for col in int_columns:
    df_data[col] = pd.to_numeric(df_data[col], errors='coerce').fillna(0).astype(int)

# For other columns, replace NaN with None (which will become NULL in SQL)
for col in df_data.columns:
    if col not in int_columns:
        df_data[col] = df_data[col].where(pd.notnull(df_data[col]), None)
# Out:
# 2023-11-28 16:44:17,622 - INFO - Data loaded successfully.

# %%
df_data_2 = df_data.drop(columns = ["portal","experiment","description","nsamples","platform","pubmeddescription"])

# %%
df_data_2= df_data_2.drop_duplicates()

# %%
print(df_data.shape,df_data.shape)
print(len(df_data["experiment"].unique()))
# Out:
# (31437, 10) (41272, 16)
# 31426

# %%
df_1.columns
# Out:
# Index(['antibodytarget', 'cellline', 'tissue', 'cid', 'compound',
#        'concentration', 'concordancetable', 'datasetid', 'factor', 'level1',
#        'level2', 'libraryid', 'lincspertid', 'nCtrSamples', 'nTrtSamples',
#        'peaktype', 'platform', 'signatureid', 'lincsSigID', 'organism',
#        'clueIoCompound', 'integratedMoas', 'GeneTargets', 'time', 'treatment',
#        'perturbagenID', 'stitchID', 'pubChemID', 'is_exemplar', 'pert_type'],
#       dtype='object')

# %%
non_success[8000:]
# Out:
# ['gdsGDS2737',
#  'gdsGDS2728',
#  'gdsGDS2724',
#  'gdsGDS2697',
#  'gdsGDS2657',
#  'gdsGDS2635',
#  'gdsGDS2628',
#  'gdsGDS2615',
#  'gdsGDS2611',
#  'gdsGDS2609',
#  'gdsGDS2604',
#  'gdsGDS2565',
#  'gdsGDS2548',
#  'gdsGDS2534',
#  'gdsGDS2526',
#  'gdsGDS2499',
#  'gdsGDS2495',
#  'gdsGDS2491',
#  'gdsGDS2486',
#  'gdsGDS2484',
#  'gdsGDS2470',
#  'gdsGDS2453',
#  'gdsGDS2432',
#  'gdsGDS2431',
#  'gdsGDS2426',
#  'gdsGDS2418',
#  'gdsGDS2414',
#  'gdsGDS2374',
#  'gdsGDS2307',
#  'gdsGDS2250',
#  'gdsGDS2221',
#  'gdsGDS2215',
#  'gdsGDS2213',
#  'gdsGDS2164',
#  'gdsGDS2154',
#  'gdsGDS2125',
#  'gdsGDS2118',
#  'gdsGDS2089',
#  'gdsGDS2088',
#  'gdsGDS2083',
#  'gdsGDS2052',
#  'gdsGDS2046',
#  'gdsGDS2023',
#  'gdsGDS1989',
#  'gdsGDS1973',
#  'gdsGDS1962',
#  'gdsGDS1917',
#  'gdsGDS1869',
#  'gdsGDS1779',
#  'gdsGDS1732',
#  'gdsGDS1673',
#  'gdsGDS1667',
#  'gdsGDS1665',
#  'gdsGDS1617',
#  'gdsGDS1604',
#  'gdsGDS1580',
#  'gdsGDS1579',
#  'gdsGDS1439',
#  'gdsGDS1413',
#  'gdsGDS1369',
#  'gdsGDS1344',
#  'gdsGDS1249',
#  'gdsGDS4401',
#  'gdsGDS1237',
#  'gdsGDS651',
#  'gdsGDS2855',
#  'gdsGDS4400',
#  'gdsGDS4399',
#  'gdsGDS2834',
#  'gdsGDS2788',
#  'gdsGDS2745',
#  'gdsGDS2656',
#  'gdsGDS2618',
#  'gdsGDS2529',
#  'gdsGDS4397',
#  'gdsGDS4396',
#  'gdsGDS2430',
#  'gdsGDS4395',
#  'gdsGDS2396',
#  'gdsGDS2382',
#  'gdsGDS2368',
#  'gdsGDS2298',
#  'gdsGDS2176',
#  'gdsGDS2143',
#  'gdsGDS2058',
#  'gdsGDS2056',
#  'gdsGDS2054',
#  'gdsGDS2040',
#  'gdsGDS2009',
#  'gdsGDS1976',
#  'gdsGDS1816',
#  'gdsGDS1559',
#  'gdsGDS1557',
#  'gdsGDS1504',
#  'gdsGDS1481',
#  'gdsGDS1334',
#  'gdsGDS1258',
#  'gdsGDS1231',
#  'gdsGDS1051',
#  'gdsGDS786',
#  'gdsGDS560',
#  'gdsGDS507',
#  'gdsGDS494',
#  'gdsGDS473',
#  'gdsGDS288',
#  'gdsGDS267',
#  'gdsGDS3218',
#  'gdsGDS2920',
#  'gdsGDS2778',
#  'gdsGDS2754',
#  'gdsGDS2676',
#  'gdsGDS2626',
#  'gdsGDS2606',
#  'gdsGDS2535',
#  'gdsGDS2478',
#  'gdsGDS2417',
#  'gdsGDS2310',
#  'gdsGDS2295',
#  'gdsGDS2038',
#  'gdsGDS1735',
#  'gdsGDS1733',
#  'gdsGDS1646',
#  'gdsGDS911',
#  'gdsGDS2790',
#  'gdsGDS2489',
#  'gdsGDS1645',
#  'gdsGDS1436',
#  'gdsGDS1210',
#  'gdsGDS781',
#  'gdsGDS670',
#  'gdsGDS533',
#  'gdsGDS504',
#  'gdsGDS412',
#  'gdsGDS337',
#  'gdsGDS183',
#  'gdsGDS171',
#  'gdsGDS170',
#  'gdsGDS157',
#  'gdsGDS2780',
#  'gdsGDS4393',
#  'gdsGDS4391',
#  'gdsGDS4390',
#  'gdsGDS2452',
#  'gdsGDS2356',
#  'gdsGDS2342',
#  'gdsGDS2321',
#  'gdsGDS2106',
#  'gdsGDS4389',
#  'gdsGDS4388',
#  'gdsGDS4387',
#  'gdsGDS4386',
#  'gdsGDS2035',
#  'gdsGDS1852',
#  'gdsGDS1449',
#  'gdsGDS1310',
#  'gdsGDS1094',
#  'gdsGDS1028',
#  'gdsGDS852',
#  'gdsGDS838',
#  'gdsGDS2546',
#  'gdsGDS1495',
#  'gdsGDS609',
#  'gdsGDS2926',
#  'gdsGDS4385',
#  'gdsGDS4384',
#  'gdsGDS4382',
#  'gdsGDS4381',
#  'gdsGDS2735',
#  'gdsGDS4380',
#  'gdsGDS2513',
#  'gdsGDS4379',
#  'gdsGDS2242',
#  'gdsGDS2230',
#  'gdsGDS1412',
#  'gdsGDS2547',
#  'gdsGDS1496',
#  'gdsGDS610',
#  'gdsGDS1627',
#  'gdsGDS848',
#  'gdsGDS847',
#  'gdsGDS846',
#  'gdsGDS845',
#  'gdsGDS1497',
#  'gdsGDS611',
#  'gdsGDS2951',
#  'gdsGDS2761',
#  'gdsGDS2696',
#  'gdsGDS2740',
#  'gdsGDS214',
#  'gdsGDS2695',
#  'gdsGDS807',
#  'gdsGDS806',
#  'gdsGDS1402',
#  'gdsGDS4377',
#  'gdsGDS1332',
#  'gdsGDS3610',
#  'gdsGDS3568',
#  'gdsGDS3559',
#  'gdsGDS4374',
#  'gdsGDS3524',
#  'gdsGDS3523',
#  'gdsGDS3517',
#  'gdsGDS4365',
#  'gdsGDS3514',
#  'gdsGDS3497',
#  'gdsGDS3483',
#  'gdsGDS3474',
#  'gdsGDS3472',
#  'gdsGDS3471',
#  'gdsGDS3439',
#  'gdsGDS3428',
#  'gdsGDS3417',
#  'gdsGDS3401',
#  'gdsGDS3383',
#  'gdsGDS3333',
#  'gdsGDS3292',
#  'gdsGDS3281',
#  'gdsGDS3262',
#  'gdsGDS3257',
#  'gdsGDS3233',
#  'gdsGDS3181',
#  'gdsGDS3139',
#  'gdsGDS3128',
#  'gdsGDS3126',
#  'gdsGDS3125',
#  'gdsGDS3124',
#  'gdsGDS3116',
#  'gdsGDS3115',
#  'gdsGDS3097',
#  'gdsGDS3096',
#  'gdsGDS3089',
#  'gdsGDS3068',
#  'gdsGDS4362',
#  'gdsGDS4361',
#  'gdsGDS3057',
#  'gdsGDS3054',
#  'gdsGDS3051',
#  'gdsGDS3049',
#  'gdsGDS3048',
#  'gdsGDS3047',
#  'gdsGDS3046',
#  'gdsGDS3045',
#  'gdsGDS3044',
#  'gdsGDS3043',
#  'gdsGDS3042',
#  'gdsGDS3034',
#  'gdsGDS3027',
#  'gdsGDS3012',
#  'gdsGDS3005',
#  'gdsGDS2954',
#  'gdsGDS2880',
#  'gdsGDS2868',
#  'gdsGDS4360',
#  'gdsGDS2865',
#  'gdsGDS2864',
#  'gdsGDS2810',
#  'gdsGDS3609',
#  'gdsGDS3606',
#  'gdsGDS3576',
#  'gdsGDS3518',
#  'gdsGDS3484',
#  'gdsGDS3459',
#  'gdsGDS3393',
#  'gdsGDS3324',
#  'gdsGDS3309',
#  'gdsGDS3160',
#  'gdsGDS3155',
#  'gdsGDS3032',
#  'gdsGDS3029',
#  'gdsGDS3011',
#  'gdsGDS3681',
#  'gdsGDS3604',
#  'gdsGDS3603',
#  'gdsGDS3602',
#  'gdsGDS3511',
#  'gdsGDS3384',
#  'gdsGDS3345',
#  'gdsGDS3192',
#  'gdsGDS3175',
#  'gdsGDS3004',
#  'gdsGDS2858',
#  'gdsGDS3560',
#  'gdsGDS3498',
#  'gdsGDS3475',
#  'gdsGDS3402',
#  'gdsGDS3129',
#  'gdsGDS2881',
#  'gdsGDS3413',
#  'gdsGDS3092',
#  'gdsGDS3088',
#  'gdsGDS3017',
#  'gdsGDS3432',
#  'gdsGDS3429',
#  'gdsGDS3268',
#  'gdsGDS3561',
#  'gdsGDS3100',
#  'gdsGDS2889',
#  'gdsGDS4358',
#  'gdsGDS3628',
#  'gdsGDS2987',
#  'gdsGDS3665',
#  'gdsGDS3113',
#  'gdsGDS4356',
#  'gdsGDS4354',
#  'gdsGDS4353',
#  'gdsGDS4350',
#  'gdsGDS4349',
#  'gdsGDS4346',
#  'gdsGDS4345',
#  'gdsGDS4342',
#  'gdsGDS4337',
#  'gdsGDS3095',
#  'gdsGDS3532',
#  'gdsGDS3531',
#  'gdsGDS3513',
#  'gdsGDS3179',
#  'gdsGDS3085',
#  'gdsGDS2808',
#  'gdsGDS3646',
#  'gdsGDS3634',
#  'gdsGDS3091',
#  'gdsGDS2447',
#  'gdsGDS3553',
#  'gdsGDS3289',
#  'gdsGDS1530',
#  'gdsGDS4336',
#  'gdsGDS2918',
#  'gdsGDS1753',
#  'gdsGDS2932',
#  'gdsGDS2448',
#  'gdsGDS2971',
#  'gdsGDS2827',
#  'gdsGDS3177',
#  'gdsGDS1768',
#  'gdsGDS4329',
#  'gdsGDS3658',
#  'gdsGDS3297',
#  'gdsGDS3640',
#  'gdsGDS3555',
#  'gdsGDS3690',
#  'gdsGDS3691',
#  'gdsGDS3649',
#  'gdsGDS3678',
#  'gdsGDS3704',
#  'gdsGDS3717',
#  'gdsGDS3710',
#  'gdsGDS4318',
#  'gdsGDS3709',
#  'gdsGDS3706',
#  'gdsGDS3688',
#  'gdsGDS4314',
#  'gdsGDS3676',
#  'gdsGDS3669',
#  'gdsGDS3668',
#  'gdsGDS3635',
#  'gdsGDS3630',
#  'gdsGDS3627',
#  'gdsGDS3615',
#  'gdsGDS3600',
#  'gdsGDS3592',
#  'gdsGDS3580',
#  'gdsGDS3578',
#  'gdsGDS3571',
#  'gdsGDS3556',
#  'gdsGDS3554',
#  'gdsGDS3539',
#  'gdsGDS3537',
#  'gdsGDS4312',
#  'gdsGDS3516',
#  'gdsGDS4308',
#  'gdsGDS4305',
#  'gdsGDS3501',
#  'gdsGDS3500',
#  'gdsGDS3499',
#  'gdsGDS3496',
#  'gdsGDS3494',
#  'gdsGDS3493',
#  'gdsGDS3487',
#  'gdsGDS3482',
#  'gdsGDS3469',
#  'gdsGDS3467',
#  'gdsGDS3463',
#  'gdsGDS3424',
#  'gdsGDS3423',
#  'gdsGDS3399',
#  'gdsGDS3388',
#  'gdsGDS3367',
#  'gdsGDS3356',
#  'gdsGDS3342',
#  'gdsGDS3330',
#  'gdsGDS3329',
#  'gdsGDS3318',
#  'gdsGDS3315',
#  'gdsGDS3313',
#  'gdsGDS3298',
#  'gdsGDS3290',
#  'gdsGDS3285',
#  'gdsGDS3283',
#  'gdsGDS3282',
#  'gdsGDS3274',
#  'gdsGDS3256',
#  'gdsGDS3191',
#  'gdsGDS3182',
#  'gdsGDS3141',
#  'gdsGDS3127',
#  'gdsGDS3119',
#  'gdsGDS3111',
#  'gdsGDS3104',
#  'gdsGDS3082',
#  'gdsGDS3073',
#  'gdsGDS3071',
#  'gdsGDS3060',
#  'gdsGDS3041',
#  'gdsGDS3007',
#  'gdsGDS3003',
#  'gdsGDS2990',
#  'gdsGDS2970',
#  'gdsGDS4304',
#  'gdsGDS2947',
#  'gdsGDS2892',
#  'gdsGDS2887',
#  'gdsGDS2883',
#  'gdsGDS2867',
#  'gdsGDS2866',
#  'gdsGDS2795',
#  'gdsGDS1269',
#  'gdsGDS1498',
#  'gdsGDS612',
#  'gdsGDS161',
#  'gdsGDS162',
#  'gdsGDS2601',
#  'gdsGDS1993',
#  'gdsGDS1974',
#  'gdsGDS1761',
#  'gdsGDS2180',
#  'gdsGDS2182',
#  'gdsGDS2183',
#  'gdsGDS2739',
#  'gdsGDS2234',
#  'gdsGDS1760',
#  'gdsGDS1252',
#  'gdsGDS1857',
#  'gdsGDS1858',
#  'gdsGDS80',
#  'gdsGDS4301',
#  'gdsGDS1777',
#  'gdsGDS1085',
#  'gdsGDS1088',
#  'gdsGDS78',
#  'gdsGDS4299',
#  'gdsGDS1830',
#  'gdsGDS1813',
#  'gdsGDS4298',
#  'gdsGDS1348',
#  'gdsGDS1523',
#  'gdsGDS625',
#  'gdsGDS1347',
#  'gdsGDS4297',
#  'gdsGDS274',
#  'gdsGDS1563',
#  'gdsGDS1568',
#  'gdsGDS1424',
#  'gdsGDS222',
#  'gdsGDS1520',
#  'gdsGDS1714',
#  'gdsGDS1836',
#  'gdsGDS2206',
#  'gdsGDS2352',
#  'gdsGDS1839',
#  'gdsGDS841',
#  'gdsGDS843',
#  'gdsGDS1774',
#  'gdsGDS1699',
#  'gdsGDS1960',
#  'gdsGDS1772',
#  'gdsGDS527',
#  'gdsGDS528',
#  'gdsGDS470',
#  'gdsGDS2415',
#  'gdsGDS2171',
#  'gdsGDS2419',
#  'gdsGDS2733',
#  'gdsGDS2831',
#  'gdsGDS2960',
#  'gdsGDS1048',
#  'gdsGDS232',
#  'gdsGDS158',
#  'gdsGDS1968',
#  'gdsGDS160',
#  'gdsGDS3705',
#  'gdsGDS3595']

# %%
df_data
# Out:
#                   platform                                        description  \
# 0      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 1      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 2      GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 3      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 4      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# ...                    ...                                                ...
# 41267  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41268  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 41269  GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 41270  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41271  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
#
#       summary                                            geolink lincsDsgc  \
# 0        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 1        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 2        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 3        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 4        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# ...       ...                                                ...       ...
# 41267    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41268    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41269    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41270    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41271    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
#
#                                            publink  \
# 0      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 1      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 2      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 3      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 4      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# ...                                            ...
# 41267  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41268  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41269  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41270  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41271  http://www.ncbi.nlm.nih.gov/pubmed/30850835
#
#                                        pubmeddescription  \
# 0      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 1      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 2      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 3      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 4      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# ...                                                  ...
# 41267  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41268  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41269  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41270  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41271  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
#
#                    experiment                              assay dataFormat  \
# 0       aflatoxin_b1_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 1       aflatoxin_b1_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 2       aflatoxin_b1_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 3               apap_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 4               apap_run2_bmd  Expression profiling by TempO-Seq       MaxD
# ...                       ...                                ...        ...
# 41267  trovafloxacin_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41268  trovafloxacin_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 41269            vpa_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 41270            vpa_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41271            vpa_run3_bmd  Expression profiling by TempO-Seq       MaxD
#
#       sampleType         dataType organism          portal   SourceID  \
# 0      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 1      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 2      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 3      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 4      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# ...          ...              ...      ...             ...        ...
# 41267  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41268  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41269  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41270  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41271  cell line  Gene Expression    human  Toxicogenomics  SRP166108
#
#        nsamples
# 0            42
# 1            42
# 2            42
# 3            42
# 4            42
# ...         ...
# 41267        42
# 41268        42
# 41269        42
# 41270        42
# 41271        42
#
# [41272 rows x 16 columns]

# %%
df_unique = df_data_2.drop_duplicates(subset='SourceID', keep='first')

# %%
df_data

# %%
df_unique["SourceID"].value_counts()
# Out:
# SourceID
# TCGA_UVM_RPPA_2019         1
# SRP166108                  1
# TCGA_PCPG_RNASeqV2_2019    1
# TCGA_PCPG_RPPA_2019        1
# TCGA_PRAD_Gistic_2020      1
#                           ..
# EDS-1014                   1
# GSE8096                    1
# E-TABM-276                 1
# GDS1363                    1
# GDS1439                    1
# Name: count, Length: 31426, dtype: int64

# %%
df_data_2[df_data_2["SourceID"] == "GDS1363"]["geolink"].to_list()[1]
# Out:
# 'http://www.ncbi.nlm.nih.gov/projects/geo/gds/gds_browse.cgi?gds=1363'

# %%
df_data_2[df_data_2["SourceID"]=="LDG-1284"]
# Out:
#                  platform summary  \
# 40957  gcpLDS1236Platform    None
# 40961  gcpLDS1265Platform    None
# 40963      GCP_2016_08_16    None
#
#                                                  geolink         lincsDsgc  \
# 40957  https://panoramaweb.org/labkey/project/LINCS/G...  broad_proteomics
# 40961  https://panoramaweb.org/labkey/project/LINCS/G...  broad_proteomics
# 40963  http://lincsportal.ccs.miami.edu/datasets/#/vi...  broad_proteomics
#
#       publink pubmeddescription assay dataFormat sampleType    dataType  \
# 40957    None              None   GCP       MaxD  cell line  Proteomics
# 40961    None              None   GCP       MaxD  cell line  Proteomics
# 40963    None              None   GCP       MaxD  cell line  Proteomics
#
#       organism  SourceID
# 40957    human  LDG-1284
# 40961    human  LDG-1284
# 40963    human  LDG-1284

# %%
print(df_data.shape)
df_data = df_data.drop_duplicates()
print(df_data.shape)
# Out:
# (41272, 16)
# (41272, 16)

# %%
success = list() ; non_success = list();

for d in df_1["datasetid"].unique():
    if d in df_unique["SourceID"].unique():
        success.append(d)
    else:
        non_success.append(d)

print(f"Success {len(success)} Non-Success {len(non_success)}")
# Out:
# Success 11 Non-Success 8491

# %%
print(len(set([str(i)+str(n) for i,n in zip(df_data["experiment"],df_data["SourceID"])])))
# Out:
# 31524

# %%
df_data["sampleType"].unique()
# Out:
# array(['cell line', 'tissue', None, 'single cell', 'tissue and cell line',
#        'xenograft'], dtype=object)

# %%
df_data
# Out:
#                   platform                                        description  \
# 0      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 1      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 2      GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 3      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 4      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# ...                    ...                                                ...
# 41267  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41268  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 41269  GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 41270  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41271  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
#
#       summary                                            geolink lincsDsgc  \
# 0        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 1        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 2        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 3        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 4        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# ...       ...                                                ...       ...
# 41267    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41268    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41269    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41270    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41271    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
#
#                                            publink  \
# 0      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 1      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 2      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 3      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 4      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# ...                                            ...
# 41267  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41268  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41269  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41270  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41271  http://www.ncbi.nlm.nih.gov/pubmed/30850835
#
#                                        pubmeddescription  \
# 0      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 1      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 2      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 3      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 4      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# ...                                                  ...
# 41267  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41268  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41269  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41270  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41271  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
#
#                    experiment                              assay dataFormat  \
# 0       aflatoxin_b1_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 1       aflatoxin_b1_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 2       aflatoxin_b1_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 3               apap_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 4               apap_run2_bmd  Expression profiling by TempO-Seq       MaxD
# ...                       ...                                ...        ...
# 41267  trovafloxacin_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41268  trovafloxacin_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 41269            vpa_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 41270            vpa_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41271            vpa_run3_bmd  Expression profiling by TempO-Seq       MaxD
#
#       sampleType         dataType organism          portal   SourceID  \
# 0      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 1      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 2      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 3      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 4      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# ...          ...              ...      ...             ...        ...
# 41267  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41268  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41269  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41270  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41271  cell line  Gene Expression    human  Toxicogenomics  SRP166108
#
#        nsamples
# 0            42
# 1            42
# 2            42
# 3            42
# 4            42
# ...         ...
# 41267        42
# 41268        42
# 41269        42
# 41270        42
# 41271        42
#
# [41272 rows x 16 columns]

# %%
a = list(df_1["datasetid"].unique())[100]
a = "GSE116436"

# %%
for c in df_data.columns:
    if a in df_data[c].to_list():
        print(c)
# Out:
# experiment
# SourceID

# %%
len(df_data["experiment"].unique())
# Out:
# 31524

# %%
for c in df_data.columns:
    print(c,len(df_data[c].unique()))
# Out:
# platform 356
# description 31510
# summary 26366
# geolink 31328
# lincsDsgc 6
# publink 2951
# pubmeddescription 2965
# experiment 31524
# assay 9
# dataFormat 1
# sampleType 6
# dataType 3
# organism 4
# portal 10
# SourceID 31426
# nsamples 466

# %%
for c in df_data.columns:
    if c not in int_columns:
        print(f"{c} str")
    else:
        print(f"{c} int")
# Out:
# platform str
# description str
# summary str
# geolink str
# lincsDsgc str
# publink str
# pubmeddescription str
# experiment str
# assay str
# dataFormat str
# sampleType str
# dataType str
# organism str
# portal str
# SourceID str
# nsamples int

# %%
df_1["datasetid"]
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 227573    GSE116436
# 227574    GSE116436
# 227575    GSE116436
# 227576    GSE116436
# 227577    GSE116436
# Name: datasetid, Length: 227578, dtype: object

# %%
i = 0
for c in df_data.iterrows():
    print(c[1])
    i+=1
    if i==2:
        break
# Out:
# platform                                           GPL16791_humanS1500
# description          Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# summary                                                           None
# geolink              https://manticore.niehs.nih.gov/cebssearch/pap...
# lincsDsgc                                                         None
# publink                    http://www.ncbi.nlm.nih.gov/pubmed/30850835
# pubmeddescription    Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# experiment                                       aflatoxin_b1_run1_bmd
# assay                                Expression profiling by TempO-Seq
# dataFormat                                                        MaxD
# sampleType                                                   cell line
# dataType                                               Gene Expression
# organism                                                         human
# portal                                                  Toxicogenomics
# SourceID                                                     SRP166108
# nsamples                                                            42
# Name: 0, dtype: object
# platform                                           GPL16791_humanS1500
# description          Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# summary                                                           None
# geolink              https://manticore.niehs.nih.gov/cebssearch/pap...
# lincsDsgc                                                         None
# publink                    http://www.ncbi.nlm.nih.gov/pubmed/30850835
# pubmeddescription    Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# experiment                                       aflatoxin_b1_run2_bmd
# assay                                Expression profiling by TempO-Seq
# dataFormat                                                        MaxD
# sampleType                                                   cell line
# dataType                                               Gene Expression
# organism                                                         human
# portal                                                  Toxicogenomics
# SourceID                                                     SRP166108
# nsamples                                                            42
# Name: 1, dtype: object

# %%
df_data["description"].to_list()[0]
# Out:
# 'Run 1 of 42 Human S1500+ TempO-Seq samples profiling gene expression in differentiated (2D-Diff) HepaRG cells exposed to Aflatoxin B1 at various concentrations and DMSO control for 96 hours.'

# %%
#print(len(set([str(i)+str(n) for i,n in zip(df_data["experiment"],df_data["portal"])])))

# %%
# 3. Connect with Database
try:
    conn = psycopg2.connect(dbname=dbname, user=user, password=password, host=host)
    logging.info("Connected to the database successfully.")
except psycopg2.OperationalError as e:
    logging.error(f"Unable to connect to the database: {e}")
    exit()

# 4. Create Cursor Object
cursor = conn.cursor()

# 5. Check if Table Exists and Delete Data if It Does
# Check if the table exists and drop it if it does
if drop_table:
    try:
        cursor.execute(f"DROP TABLE IF EXISTS {table_name};")
        conn.commit()
        print(f"Table {table_name} dropped successfully if it existed.")
    except psycopg2.Error as e:
        print(f"An error occurred: {e}")
        conn.rollback()


cursor.execute("SELECT EXISTS(SELECT * FROM information_schema.tables WHERE table_name=%s)", (table_name,))
table_exists = cursor.fetchone()[0]

if table_exists:
    try:
        cursor.execute(f"DELETE FROM {table_name};")
        conn.commit()
        logging.info(f"Existing data in table {table_name} deleted successfully.")
    except psycopg2.Error as e:
        logging.error(f"An error occurred while deleting data from the table: {e}")
        cursor.close()
        conn.close()
        exit()
else:
    # Create table if it does not exist
    column_text = ", ".join(f"{c} VARCHAR({n + 10})" if c not in int_columns else f"{c} INT" for c, n in zip(df_data.columns, max_lengths))
    create_table_query = f"CREATE TABLE {table_name} ({column_text}, PRIMARY KEY({primary_keys[0]},{primary_keys[1]}), FOREIGN KEY ({foreign_key}) REFERENCES {parent_table}({parent_id}));"
    try:
        cursor.execute(create_table_query)
        conn.commit()
        logging.info(f"Table {table_name} created successfully.")
    except psycopg2.Error as e:
        logging.error(f"An error occurred while creating the table: {e}")
        cursor.close()
        conn.close()
        exit()
# Out:
# 2023-11-27 15:42:05,380 - INFO - Connected to the database successfully.
# 2023-11-27 15:42:05,387 - ERROR - An error occurred while creating the table: there is no unique constraint matching given keys for referenced table "signatures"
# Table datasets dropped successfully if it existed.

# %%
# 6. Dump Data into Table
data_tuples = list(df_data.itertuples(index=False, name=None))
insert_query = f"INSERT INTO {table_name} ({', '.join(df_data.columns)}) VALUES (%s" + ", %s"*(len(df_data.columns)-1) + ")"

try:
    with conn:
        with conn.cursor() as curs:
            for record in data_tuples:
                try:
                    curs.execute(insert_query, record)
                except psycopg2.Error as e:
                    logging.error(f"Error inserting record {record}: {e}")
                    # Optionally, you can break the loop after logging the first error
                    break  
    logging.info(f"Data dumped into {table_name} successfully.")
except psycopg2.Error as e:
    logging.error(f"An error occurred while inserting data into the table: {e}")
    conn.rollback()
    exit()
# Out:
# 2023-11-27 14:25:48,774 - INFO - Data dumped into datasets successfully.

# %%
df_data
# Out:
#                   platform                                        description  \
# 0      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 1      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 2      GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 3      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 4      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# ...                    ...                                                ...
# 41267  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41268  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 41269  GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 41270  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41271  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
#
#       summary                                            geolink lincsDsgc  \
# 0        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 1        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 2        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 3        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 4        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# ...       ...                                                ...       ...
# 41267    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41268    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41269    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41270    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41271    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
#
#                                            publink  \
# 0      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 1      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 2      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 3      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 4      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# ...                                            ...
# 41267  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41268  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41269  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41270  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41271  http://www.ncbi.nlm.nih.gov/pubmed/30850835
#
#                                        pubmeddescription  \
# 0      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 1      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 2      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 3      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 4      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# ...                                                  ...
# 41267  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41268  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41269  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41270  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41271  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
#
#                    experiment                              assay dataFormat  \
# 0       aflatoxin_b1_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 1       aflatoxin_b1_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 2       aflatoxin_b1_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 3               apap_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 4               apap_run2_bmd  Expression profiling by TempO-Seq       MaxD
# ...                       ...                                ...        ...
# 41267  trovafloxacin_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41268  trovafloxacin_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 41269            vpa_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 41270            vpa_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41271            vpa_run3_bmd  Expression profiling by TempO-Seq       MaxD
#
#       sampleType         dataType organism          portal   SourceID  \
# 0      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 1      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 2      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 3      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 4      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# ...          ...              ...      ...             ...        ...
# 41267  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41268  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41269  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41270  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41271  cell line  Gene Expression    human  Toxicogenomics  SRP166108
#
#        nsamples
# 0            42
# 1            42
# 2            42
# 3            42
# 4            42
# ...         ...
# 41267        42
# 41268        42
# 41269        42
# 41270        42
# 41271        42
#
# [41272 rows x 16 columns]

# %% [markdown]
# ## Create Table Compounds

# %%
# 1. Imports, Variables, Functions
import psycopg2
import pandas as pd
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# SQL variables
dbname = "ilincs"
user = "ddalton"
password = "Teclado$$$111"
host = "localhost"
path_data = "../../data/iLINCS/compounds.csv"
table_name = "compounds"
primary_keys = []
int_columns = ["pubchemcid"]  # INT columns - rest TEXT
drop_table = True
foreign_key = ""
parent_table = ""
parent_id = ""
# 2. Load Data
try:
    df_data = pd.read_csv(path_data)
    logging.info("Data loaded successfully.")
except FileNotFoundError:
    logging.error("Data file not found. Please check the file path.")
    exit()
# Out:
# 2023-11-27 16:20:58,366 - INFO - Data loaded successfully.

# %%
print(df_data.shape)
sum(df_data["stitchid"].notnull())
# Out:
# (21299, 5)
# 20752

# %%
print(df_data.shape)
for c in df_data.columns:
    print(c, len(df_data[c].unique()))
# Out:
# (21299, 5)
# perturbagenid 21299
# pubchemcid 21026
# stitchid 20543
# compound 21122
# lincspertid 21174

# %%
for c in df_data.columns:
    if c not in int_columns:
        print(f"{c} str")
    else:
        print(f"{c} int")
# Out:
# perturbagenid str
# pubchemcid int
# stitchid str
# compound str
# lincspertid str

# %%
df_data["perturbagenid"]
# Out:
# 0               BRD-A00100033
# 1               BRD-A00147595
# 2               BRD-A00150179
# 3               BRD-A00218260
# 4               BRD-A00267231
#                  ...
# 21294           CMAP-ERGKD328
# 21295        CMAP-PRISM-1B-NR
# 21296    CMAP-PRISM-1B-PARENT
# 21297          CMAP-PRISM-TP7
# 21298     CMAP-T2DTUNICAMYCIN
# Name: perturbagenid, Length: 21299, dtype: object

# %%
df_1 = pd.read_csv("../../data/iLINCS/signatures.csv")
df_1.columns
# Out:
# /tmp/ipykernel_169994/2807596933.py:1: DtypeWarning: Columns (0,3,7,8,9,10,15,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv("../../data/iLINCS/signatures.csv")
# Index(['antibodytarget', 'cellline', 'tissue', 'cid', 'compound',
#        'concentration', 'concordancetable', 'datasetid', 'factor', 'level1',
#        'level2', 'libraryid', 'lincspertid', 'nCtrSamples', 'nTrtSamples',
#        'peaktype', 'platform', 'signatureid', 'lincsSigID', 'organism',
#        'clueIoCompound', 'integratedMoas', 'GeneTargets', 'time', 'treatment',
#        'perturbagenID', 'stitchID', 'pubChemID', 'is_exemplar', 'pert_type'],
#       dtype='object')

# %% [markdown]
# ## Create Table Genes

# %%
# 1. Imports, Variables, Functions
import psycopg2
import pandas as pd
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# SQL variables
dbname = "ilincs"
user = "ddalton"
password = "Teclado$$$111"
host = "localhost"
path_data = "../../data/iLINCS/genes.csv"
table_name = "genes"
primary_keys = []
int_columns = []  # INT columns - rest TEXT
drop_table = True
foreign_key = ""
parent_table = ""
parent_id = ""
# 2. Load Data
try:
    df_data = pd.read_csv(path_data)
    logging.info("Data loaded successfully.")
except FileNotFoundError:
    logging.error("Data file not found. Please check the file path.")
    exit()
# Out:
# 2023-11-27 16:06:40,379 - INFO - Data loaded successfully.

# %%
df_data
# Out:
#        chromosome                                            dbxrefs  \
# 0              19  MIM:138670|HGNC:HGNC:5|Ensembl:ENSG00000121410...
# 1              12  MIM:103950|HGNC:HGNC:7|Ensembl:ENSG00000175899...
# 2              12                HGNC:HGNC:8|Ensembl:ENSG00000256069
# 3              11                                 HGNC:11|MIM:108985
# 4               8  MIM:108345|HGNC:HGNC:7645|Ensembl:ENSG00000171...
# ...           ...                                                ...
# 235977          3                                                  -
# 235978          7                                                  -
# 235979         12                                                  -
# 235980          1                                                  -
# 235981          5                                                  -
#
#                                               description     geneid  \
# 0                                  alpha-1-B glycoprotein          1
# 1                                   alpha-2-macroglobulin          2
# 2                      alpha-2-macroglobulin pseudogene 1          3
# 3       atrophia areata, peripapillary chorioretinal d...          8
# 4       N-acetyltransferase 1 (arylamine N-acetyltrans...          9
# ...                                                   ...        ...
# 235977                  ribosomal protein S27a pseudogene  105650979
# 235978                  ribosomal protein S27a pseudogene  105650980
# 235979   NLR family, pyrin domain containing 5 pseudogene  105661729
# 235980  long intergenic non-coding RNA muscle differen...  105661730
# 235981                        long non-coding RNA LncTCF7  105664404
#
#         homologeneid locustag maplocation  \
# 0            11167.0        -     19q13.4
# 1            37248.0        -    12p13.31
# 2                NaN        -    12p13.31
# 3                NaN        -       11p15
# 4            37329.0        -        8p22
# ...              ...      ...         ...
# 235977           NaN        -           -
# 235978           NaN        -           -
# 235979           NaN        -           -
# 235980           NaN        -           -
# 235981           NaN        -           -
#
#                                               namenomauth nomstatus  \
# 0                                  alpha-1-B glycoprotein         O
# 1                                   alpha-2-macroglobulin         O
# 2                      alpha-2-macroglobulin pseudogene 1         O
# 3       atrophia areata, peripapillary chorioretinal d...         0
# 4       N-acetyltransferase 1 (arylamine N-acetyltrans...         O
# ...                                                   ...       ...
# 235977                                                  -         -
# 235978                                                  -         -
# 235979                                                  -         -
# 235980                                                  -         -
# 235981                                                  -         -
#
#               symbol symbonomauth                   synonyms  taxid  \
# 0               A1BG         A1BG       A1B|ABG|GAB|HYST2477   9606
# 1                A2M          A2M  A2MD|CPAMD5|FWP007|S863-7   9606
# 2              A2MP1        A2MP1                       A2MP   9606
# 3                 AA           AA                          -   9606
# 4               NAT1         NAT1       AAC1|MNAT|NAT-1|NATI   9606
# ...              ...          ...                        ...    ...
# 235977  LOC105650979            -                          -  10116
# 235978  LOC105650980            -                          -  10116
# 235979  LOC105661729            -                          -  10090
# 235980      Linc-md1            -                          -  10090
# 235981       LNCTCF7            -             TCONS_00009511   9606
#
#             typeofgene
# 0       protein-coding
# 1       protein-coding
# 2               pseudo
# 3              unknown
# 4       protein-coding
# ...                ...
# 235977          pseudo
# 235978          pseudo
# 235979          pseudo
# 235980           ncRNA
# 235981           ncRNA
#
# [235982 rows x 14 columns]

# %% [markdown]
# ## Query

# %%
# SQL variables
dbname = "ilincs"
user = "ddalton"
password = "Teclado$$$111"
host = "localhost"
table_name = "datasets"

# Connect to the database
try:
    conn = psycopg2.connect(dbname=dbname, user=user, password=password, host=host)
    print("Connected to the database successfully.")
except psycopg2.OperationalError as e:
    print(f"Unable to connect to the database: {e}")
    exit()

# Query the table
try:
    query = f"SELECT * FROM {table_name} LIMIT 10;"  # Adjust the query as needed
    query = f"SELECT * FROM {table_name} WHERE antibodytarget IS NOT NULL;"
    query = f"SELECT * FROM {table_name} WHERE experiment IS  NULL;"
    query = f"SELECT * FROM {table_name}"
    df = pd.read_sql(query, conn)
    print(df)
except Exception as e:
    print(f"An error occurred while querying the table: {e}")
finally:
    conn.close()

# The DataFrame 'df' now contains the first 10 rows of the table.
# Out:
# Connected to the database successfully.
#                   platform                                        description  \
# 0      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 1      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 2      GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 3      GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 4      GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# ...                    ...                                                ...
# 41267  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41268  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
# 41269  GPL16791_humanS1500  Run 1 of 42 Human S1500+ TempO-Seq samples pro...
# 41270  GPL16791_humanS1500  Run 2 of 42 Human S1500+ TempO-Seq samples pro...
# 41271  GPL16791_humanS1500  Run 3 of 42 Human S1500+ TempO-Seq samples pro...
#
#       summary                                            geolink lincsdsgc  \
# 0        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 1        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 2        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 3        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 4        None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# ...       ...                                                ...       ...
# 41267    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41268    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41269    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41270    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
# 41271    None  https://manticore.niehs.nih.gov/cebssearch/pap...      None
#
#                                            publink  \
# 0      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 1      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 2      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 3      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 4      http://www.ncbi.nlm.nih.gov/pubmed/30850835
# ...                                            ...
# 41267  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41268  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41269  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41270  http://www.ncbi.nlm.nih.gov/pubmed/30850835
# 41271  http://www.ncbi.nlm.nih.gov/pubmed/30850835
#
#                                        pubmeddescription  \
# 0      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 1      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 2      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 3      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 4      Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# ...                                                  ...
# 41267  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41268  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41269  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41270  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
# 41271  Ramaiahgari SC, Auerbach SS, Saddler TO, et al...
#
#                    experiment                              assay dataformat  \
# 0       aflatoxin_b1_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 1       aflatoxin_b1_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 2       aflatoxin_b1_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 3               apap_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 4               apap_run2_bmd  Expression profiling by TempO-Seq       MaxD
# ...                       ...                                ...        ...
# 41267  trovafloxacin_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41268  trovafloxacin_run3_bmd  Expression profiling by TempO-Seq       MaxD
# 41269            vpa_run1_bmd  Expression profiling by TempO-Seq       MaxD
# 41270            vpa_run2_bmd  Expression profiling by TempO-Seq       MaxD
# 41271            vpa_run3_bmd  Expression profiling by TempO-Seq       MaxD
#
#       sampletype         datatype organism          portal   sourceid  \
# 0      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 1      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 2      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 3      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 4      cell line  Gene Expression    human  Toxicogenomics  SRP166108
# ...          ...              ...      ...             ...        ...
# 41267  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41268  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41269  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41270  cell line  Gene Expression    human  Toxicogenomics  SRP166108
# 41271  cell line  Gene Expression    human  Toxicogenomics  SRP166108
#
#        nsamples
# 0            42
# 1            42
# 2            42
# 3            42
# 4            42
# ...         ...
# 41267        42
# 41268        42
# 41269        42
# 41270        42
# 41271        42
#
# [41272 rows x 16 columns]
# /tmp/ipykernel_157820/3831847141.py:22: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
